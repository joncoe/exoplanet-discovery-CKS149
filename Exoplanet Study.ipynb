# %% [markdown]
# # A Study of Exoplanets
#
# Data source: <a href="https://exoplanetarchive.ipac.caltech.edu/cgi-bin/TblView/nph-tblView?app=ExoTbls&config=PS" target="_blank">https://exoplanetarchive.ipac.caltech.edu/cgi-bin/TblView/nph-tblView?app=ExoTbls&config=PS</a>

# %%
import pandas as pd
import numpy as np

# %%
dataFile = "exoplanets-data-23-12.csv"
exoplanets = pd.DataFrame(pd.read_csv(dataFile))
exoplanets
# Out:
#             pl_name    hostname  default_flag  sy_snum  sy_pnum  \
# 0          11 Com b      11 Com             0        2        1
# 1          11 Com b      11 Com             0        2        1
# 2          11 Com b      11 Com             1        2        1
# 3          11 UMi b      11 UMi             1        1        1
# 4          11 UMi b      11 UMi             0        1        1
# ...             ...         ...           ...      ...      ...
# 14821  Kepler-170 b  Kepler-170             0        1        2
# 14822  Kepler-170 b  Kepler-170             0        1        2
# 14823  Kepler-170 b  Kepler-170             0        1        2
# 14824  Kepler-170 b  Kepler-170             1        1        2
# 14825  Kepler-170 b  Kepler-170             0        1        2
#
#        discoverymethod  disc_year                           disc_facility  \
# 0      Radial Velocity       2007                        Xinglong Station
# 1      Radial Velocity       2007                        Xinglong Station
# 2      Radial Velocity       2007                        Xinglong Station
# 3      Radial Velocity       2009  Thueringer Landessternwarte Tautenburg
# 4      Radial Velocity       2009  Thueringer Landessternwarte Tautenburg
# ...                ...        ...                                     ...
# 14821          Transit       2014                                  Kepler
# 14822          Transit       2014                                  Kepler
# 14823          Transit       2014                                  Kepler
# 14824          Transit       2014                                  Kepler
# 14825          Transit       2014                                  Kepler
#
#                                               soltype  pl_controv_flag  ...  \
# 0                                 Published Confirmed                0  ...
# 1                                 Published Confirmed                0  ...
# 2                                 Published Confirmed                0  ...
# 3                                 Published Confirmed                0  ...
# 4                                 Published Confirmed                0  ...
# ...                                               ...              ...  ...
# 14821           Kepler Project Candidate (q1_q16_koi)                0  ...
# 14822  Kepler Project Candidate (q1_q17_dr25_sup_koi)                0  ...
# 14823      Kepler Project Candidate (q1_q17_dr24_koi)                0  ...
# 14824                             Published Confirmed                0  ...
# 14825                             Published Confirmed                0  ...
#
#       sy_vmagerr2  sy_kmag  sy_kmagerr1  sy_kmagerr2  sy_gaiamag  \
# 0          -0.023    2.282        0.346       -0.346     4.44038
# 1          -0.023    2.282        0.346       -0.346     4.44038
# 2          -0.023    2.282        0.346       -0.346     4.44038
# 3          -0.005    1.939        0.270       -0.270     4.56216
# 4          -0.005    1.939        0.270       -0.270     4.56216
# ...           ...      ...          ...          ...         ...
# 14821      -0.103   12.677        0.024       -0.024    14.34690
# 14822      -0.103   12.677        0.024       -0.024    14.34690
# 14823      -0.103   12.677        0.024       -0.024    14.34690
# 14824      -0.103   12.677        0.024       -0.024    14.34690
# 14825         NaN      NaN          NaN          NaN         NaN
#
#        sy_gaiamagerr1  sy_gaiamagerr2   rowupdate  pl_pubdate  releasedate
# 0            0.003848       -0.003848  2014-07-23     2011-08   2014-07-23
# 1            0.003848       -0.003848  2014-05-14     2008-01   2014-05-14
# 2            0.003848       -0.003848  2023-09-19     2023-08   2023-09-19
# 3            0.003903       -0.003903  2018-09-04     2017-03   2018-09-06
# 4            0.003903       -0.003903  2018-04-25     2011-08   2014-07-23
# ...               ...             ...         ...         ...          ...
# 14821        0.000260       -0.000260  2014-11-21  2014-12-18   2014-11-21
# 14822        0.000260       -0.000260  2018-09-25  2018-08-16   2018-09-25
# 14823        0.000260       -0.000260  2015-08-25  2015-09-24   2015-08-25
# 14824        0.000260       -0.000260  2014-05-14     2014-03   2014-05-14
# 14825             NaN             NaN         NaN         NaN          NaN
#
# [14826 rows x 92 columns]
