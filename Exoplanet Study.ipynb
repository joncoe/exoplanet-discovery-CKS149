# %% [markdown]
# # A Study of Exoplanets
#
# Data source: <a href="https://exoplanetarchive.ipac.caltech.edu/cgi-bin/TblView/nph-tblView?app=ExoTbls&config=PS" target="_blank">https://exoplanetarchive.ipac.caltech.edu/cgi-bin/TblView/nph-tblView?app=ExoTbls&config=PS</a>

# %%
import pandas as pd
import numpy as np
# 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataFile = "exoplanets-data-23-12-CONFIRMED.csv"
exoplanets = pd.DataFrame(pd.read_csv(dataFile))
exoplanets
# Out:
#          pl_name hostname  default_flag  sy_snum  sy_pnum  discoverymethod  \
# 0       11 Com b   11 Com             0        2        1  Radial Velocity
# 1       11 Com b   11 Com             0        2        1  Radial Velocity
# 2       11 Com b   11 Com             1        2        1  Radial Velocity
# 3       11 UMi b   11 UMi             1        1        1  Radial Velocity
# 4       11 UMi b   11 UMi             0        1        1  Radial Velocity
# ...          ...      ...           ...      ...      ...              ...
# 35149  ups And d  ups And             0        2        3  Radial Velocity
# 35150  ups Leo b  ups Leo             1        1        1  Radial Velocity
# 35151   xi Aql b   xi Aql             0        1        1  Radial Velocity
# 35152   xi Aql b   xi Aql             0        1        1  Radial Velocity
# 35153   xi Aql b   xi Aql             1        1        1  Radial Velocity
#
# ...

# %%
exoplanets.describe()
# Out:
#        default_flag       sy_snum       sy_pnum     disc_year  \
# count  35154.000000  35154.000000  35154.000000  35154.000000
# mean       0.157877      1.081612      1.878136   2015.296183
# std        0.364631      0.302506      1.192075      3.777900
# min        0.000000      1.000000      1.000000   1992.000000
# 25%        0.000000      1.000000      1.000000   2014.000000
# 50%        0.000000      1.000000      1.000000   2016.000000
# 75%        0.000000      1.000000      2.000000   2016.000000
# max        1.000000      4.000000      8.000000   2023.000000
#
#        pl_controv_flag     pl_orbper  pl_orbpererr1  pl_orbpererr2  \
# count     35154.000000  3.208400e+04   3.074700e+04   3.074600e+04
# mean          0.001906  1.360537e+04   1.567729e+04  -3.692960e+03
# std           0.043616  2.245608e+06   2.680574e+06   5.716174e+05
# min           0.000000  9.070629e-02   0.000000e+00  -1.000000e+08
# 25%           0.000000  4.458167e+00   8.750000e-06  -2.077500e-04
# ...

# %%
unique_planets_df = exoplanets.groupby('pl_name').first().reset_index()
unique_planets_df.describe()
# Out:
#        default_flag      sy_snum     sy_pnum    disc_year  pl_controv_flag  \
# count   5550.000000  5550.000000  5550.00000  5550.000000      5550.000000
# mean       0.313694     1.101802     1.77009  2016.123604         0.005225
# std        0.464035     0.338943     1.14561     4.496113         0.072103
# min        0.000000     1.000000     1.00000  1992.000000         0.000000
# 25%        0.000000     1.000000     1.00000  2014.000000         0.000000
# 50%        0.000000     1.000000     1.00000  2016.000000         0.000000
# 75%        1.000000     1.000000     2.00000  2020.000000         0.000000
# max        1.000000     4.000000     8.00000  2023.000000         1.000000
#
#           pl_orbper  pl_orbpererr1  pl_orbpererr2  pl_orbperlim   pl_orbsmax  \
# count  5.307000e+03   5.294000e+03   5.294000e+03   5307.000000  5248.000000
# mean   8.059794e+04   9.041221e+04  -2.065437e+04     -0.001319     6.707503
# ...

# %%
len(unique_planets_df.index)
# Out:
# 5550

# %%
correlations = unique_planets_df.corr()
correlations
# Out:
# /var/folders/8v/qv_jstgn2zl7y_9k9ss5tvbc0000gn/T/ipykernel_13420/246804950.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlations = unique_planets_df.corr()
#                  default_flag   sy_snum   sy_pnum  disc_year  pl_controv_flag  \
# default_flag         1.000000  0.063893 -0.009060   0.170491         0.074883
# sy_snum              0.063893  1.000000  0.031977  -0.160099         0.066718
# sy_pnum             -0.009060  0.031977  1.000000  -0.115433         0.062544
# disc_year            0.170491 -0.160099 -0.115433   1.000000        -0.031455
# pl_controv_flag      0.074883  0.066718  0.062544  -0.031455         1.000000
# ...                       ...       ...       ...        ...              ...
# sy_kmagerr1         -0.000589 -0.006386 -0.025209  -0.009788         0.000978
# ...

# %%
sns.heatmap(correlations,cmap='coolwarm')
# Out:
# <Axes: >

# %%
# sns.swarmplot(x="sy_snum", y="sy_pnum", data=unique_planets_df)
