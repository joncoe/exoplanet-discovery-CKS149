# %% [markdown]
# # Active Satellites
#
# Let's play around with data about artificial satellites orbiting the earth. 🛰 🌎   🛰️
#
# I am also considering doing something with star chart data or exoplanet data.

# %%
import pandas as pd
# all active satellites 
active_satellites = "https://celestrak.org/NORAD/elements/gp.php?GROUP=active&FORMAT=json"
active_df = pd.read_json(active_satellites)
active_df.sample(10)
# Out:
#                OBJECT_NAME   OBJECT_ID                       EPOCH  \
# 206            COSMOS 2416   2005-048A  2023-11-17T09:33:57.464064
# 6881         STARLINK-5065   2023-021P  2023-11-17T22:00:01.999584
# 806            COSMOS 2502   2014-086A  2023-11-17T19:35:12.056064
# 7014           ONEWEB-0666  2023-029AG  2023-11-17T22:00:01.999584
# 4544  JILIN-1 GAOFEN 03D17   2022-019Q  2023-11-17T19:45:45.368064
# 4799         STARLINK-3758  2022-041AN  2023-11-17T04:27:51.875712
# 2596           GONETS-M 21   2020-091B  2023-11-17T20:04:04.795968
# 3731           ONEWEB-0257   2021-060J  2023-11-17T12:17:57.781248
# 2516         STARLINK-1933  2020-074BE  2023-11-17T06:08:04.975296
# 8668        STARLINK-30577   2023-158C  2023-11-17T22:00:01.999584
#
#       MEAN_MOTION  ECCENTRICITY  INCLINATION  RA_OF_ASC_NODE  \
# 206     12.555452      0.000819      82.4703        190.5270
# 6881    14.983105      0.000302      70.0005        149.4011
# ...

# %% [markdown]
# ## Let's filter all active satellites for starlink

# %%
starlink = active_df[active_df['OBJECT_NAME'].str.contains('STARLINK')]
starlink.sample(10)
# Out:
#          OBJECT_NAME   OBJECT_ID                       EPOCH  MEAN_MOTION  \
# 2944   STARLINK-2158   2021-017Y  2023-11-17T12:12:57.863520    15.063872
# 3856   STARLINK-3060  2021-082AB  2023-11-17T10:50:20.646240    14.983296
# 8718  STARLINK-30617   2023-161H  2023-11-17T22:00:01.999584    15.303397
# 6937   STARLINK-5565   2023-028E  2023-11-17T16:47:42.542880    14.983478
# 3218   STARLINK-2421   2021-027G  2023-11-17T08:52:37.647552    15.063904
# 7716   STARLINK-6175   2023-083G  2023-11-17T10:48:15.136416    15.025391
# 7359   STARLINK-5552   2023-058Y  2023-11-17T13:20:42.165312    15.012584
# 4702   STARLINK-3735  2022-029AE  2023-11-17T20:08:29.749344    15.088227
# 8596  STARLINK-30489   2023-151L  2023-11-17T12:14:30.938784    15.159526
# 2039   STARLINK-1408  2020-035AH  2023-11-17T09:44:43.160640    15.261879
#
#       ECCENTRICITY  INCLINATION  RA_OF_ASC_NODE  ARG_OF_PERICENTER  \
# 2944      0.000128      53.0563         26.7577            93.6372
# ...

# %%
total_starlink = starlink.shape[0]
print("Right now Nov 16 2023 there are " + str(total_starlink) + " Starlinks in orbit")
# Out:
# Right now Nov 16 2023 there are 5049 Starlinks in orbit

# %%
print("I don't yet know enough about what I am comparing here ¯\_(ツ)_/¯, but let's make a visualization for the sake of doing so.")

import matplotlib.pyplot as plt

starlink.plot(kind='scatter', x='MEAN_ANOMALY', y='MEAN_MOTION', color='blue')
plt.show()
# Out:
# I don't yet know enough about what I am comparing here ¯\_(ツ)_/¯, but let's make a visualization for the sake of doing so.
